# %%
import pandas as pd
import numpy as np
import altair

# %%
tb = pd.read_csv('../data/processed_2019q1_partial.csv', header=0, nrows=100)
tb.drop('Unnamed: 0', axis=1, inplace=True)

# %%
tb.head()
# Out:
#    POOL_ID       LOAN_ID  ACT_PERIOD CHANNEL  \
# 0      NaN  100000913397       12019       C
# 1      NaN  100000913397       22019       C
# 2      NaN  100000913397       32019       C
# 3      NaN  100000913397       42019       C
# 4      NaN  100000913397       52019       C
#
#                                       SELLER SERVICER  MASTER_SERVICER  \
# 0  Jpmorgan Chase Bank, National Association    Other              NaN
# 1  Jpmorgan Chase Bank, National Association    Other              NaN
# 2  Jpmorgan Chase Bank, National Association    Other              NaN
# 3  Jpmorgan Chase Bank, National Association    Other              NaN
# 4  Jpmorgan Chase Bank, National Association    Other              NaN
#
#    ORIG_RATE  CURR_RATE  ORIG_UPB  ...  MARGIN  BALLOON_INDICATOR  \
# 0      5.875      5.875    324000  ...     NaN                NaN
# 1      5.875      5.875    324000  ...     NaN                NaN
# ...
